# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(1)
import tensorflow as tf
tf.random.set_seed(2)
import statsmodels.api as sm
import time

from ChemClean import *
from Descriptors import *

# %%
#Keras/TensorFlow
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten,Dense, Softmax
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

#Keras image processing
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

# %%
#Sklearn tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#Keras specials
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ## Load csv files into DataFrames

# %%
features=pd.read_csv('features_train.csv',index_col=0)
target=pd.read_csv('target_train.csv',index_col=0)['ERed']

features_std = StandardScaler().fit_transform(features)

# %%
features_std=tf.convert_to_tensor(features_std,dtype=tf.float64)
target=tf.convert_to_tensor(target,dtype=tf.float64)

# %%
num_dens_layers=4     
n_nodes=[64, 32,16, 1]
learning_rate=6e-4

model = Sequential()
model.add(Dense(n_nodes[0], kernel_initializer='normal',input_dim = features.shape[1], activation='relu')) # first hidden layer
# model.add(Dropout(0.5))
for i in range(1,num_dens_layers): # loop through the rest of hidden layers
    model.add(Dense(n_nodes[i], kernel_initializer='normal',activation='relu'))    

model.compile(loss='mean_absolute_error', optimizer=Adam(learning_rate=learning_rate), metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_23 (Dense)            (None, 64)                2112
#
#  dense_24 (Dense)            (None, 32)                2080
#
#  dense_25 (Dense)            (None, 16)                528
#
#  dense_26 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

with tf.device('/cpu:0'):

    redlr=ReduceLROnPlateau(monitor='val_mean_absolute_error', factor=0.9, patience=5, min_lr=0, verbose=1)

    history=model.fit(features_std, target, epochs=50, batch_size=32, validation_split = 0.15, callbacks=redlr, verbose=True)

    train_err=history.history['mean_absolute_error']

    val_err=history.history['val_mean_absolute_error']

    plt.figure()
    plt.plot(train_err, label='Training')
    plt.plot(val_err, label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
# Out:
# Epoch 1/50
# 116/116 [==============================] - 1s 4ms/step - loss: 0.7766 - mean_absolute_error: 0.7766 - val_loss: 0.1673 - val_mean_absolute_error: 0.1673 - lr: 6.0000e-04
# Epoch 2/50
# 116/116 [==============================] - 0s 3ms/step - loss: 0.1283 - mean_absolute_error: 0.1283 - val_loss: 0.1118 - val_mean_absolute_error: 0.1118 - lr: 6.0000e-04
# Epoch 3/50
# 116/116 [==============================] - 0s 3ms/step - loss: 0.0963 - mean_absolute_error: 0.0963 - val_loss: 0.0908 - val_mean_absolute_error: 0.0908 - lr: 6.0000e-04
# Epoch 4/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0825 - mean_absolute_error: 0.0825 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815 - lr: 6.0000e-04
# Epoch 5/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0759 - mean_absolute_error: 0.0759 - val_loss: 0.0761 - val_mean_absolute_error: 0.0761 - lr: 6.0000e-04
# Epoch 6/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0714 - mean_absolute_error: 0.0714 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717 - lr: 6.0000e-04
# Epoch 7/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0688 - mean_absolute_error: 0.0688 - val_loss: 0.0692 - val_mean_absolute_error: 0.0692 - lr: 6.0000e-04
# Epoch 8/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0667 - mean_absolute_error: 0.0667 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685 - lr: 6.0000e-04
# Epoch 9/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0640 - mean_absolute_error: 0.0640 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717 - lr: 6.0000e-04
# Epoch 10/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646 - lr: 6.0000e-04
# Epoch 11/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659 - lr: 6.0000e-04
# Epoch 12/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0600 - mean_absolute_error: 0.0600 - val_loss: 0.0667 - val_mean_absolute_error: 0.0667 - lr: 6.0000e-04
# Epoch 13/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0606 - mean_absolute_error: 0.0606 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618 - lr: 6.0000e-04
# Epoch 14/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0597 - mean_absolute_error: 0.0597 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - lr: 6.0000e-04
# Epoch 15/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0579 - mean_absolute_error: 0.0579 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627 - lr: 6.0000e-04
# Epoch 16/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0624 - val_mean_absolute_error: 0.0624 - lr: 6.0000e-04
# Epoch 17/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - lr: 6.0000e-04
# Epoch 18/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - lr: 6.0000e-04
# Epoch 19/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0563 - mean_absolute_error: 0.0563 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - lr: 6.0000e-04
# Epoch 20/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618 - lr: 6.0000e-04
# Epoch 21/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - val_loss: 0.0601 - val_mean_absolute_error: 0.0601 - lr: 6.0000e-04
# Epoch 22/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - lr: 6.0000e-04
# Epoch 23/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - lr: 6.0000e-04
# Epoch 24/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0596 - val_mean_absolute_error: 0.0596 - lr: 6.0000e-04
# Epoch 25/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0552 - mean_absolute_error: 0.0552 - val_loss: 0.0623 - val_mean_absolute_error: 0.0623 - lr: 6.0000e-04
# Epoch 26/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0542 - mean_absolute_error: 0.0542 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - lr: 6.0000e-04
# Epoch 27/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0546 - mean_absolute_error: 0.0546 - val_loss: 0.0610 - val_mean_absolute_error: 0.0610 - lr: 6.0000e-04
# Epoch 28/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0541 - mean_absolute_error: 0.0541 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - lr: 6.0000e-04
# Epoch 29/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - lr: 6.0000e-04
# Epoch 30/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0546 - mean_absolute_error: 0.0546 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - lr: 6.0000e-04
# Epoch 31/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0534 - mean_absolute_error: 0.0534 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - lr: 6.0000e-04
# Epoch 32/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0536 - mean_absolute_error: 0.0536 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - lr: 6.0000e-04
# Epoch 33/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0541 - mean_absolute_error: 0.0541 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - lr: 6.0000e-04
# Epoch 34/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0526 - mean_absolute_error: 0.0526 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - lr: 6.0000e-04
# Epoch 35/50
# 112/116 [===========================>..] - ETA: 0s - loss: 0.0532 - mean_absolute_error: 0.0532
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0005400000256486237.
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0533 - mean_absolute_error: 0.0533 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - lr: 6.0000e-04
# Epoch 36/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0527 - mean_absolute_error: 0.0527 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - lr: 5.4000e-04
# Epoch 37/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - lr: 5.4000e-04
# Epoch 38/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0521 - mean_absolute_error: 0.0521 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - lr: 5.4000e-04
# Epoch 39/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - lr: 5.4000e-04
# Epoch 40/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0528 - mean_absolute_error: 0.0528 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - lr: 5.4000e-04
# Epoch 41/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - lr: 5.4000e-04
# Epoch 42/50
#  90/116 [======================>.......] - ETA: 0s - loss: 0.0510 - mean_absolute_error: 0.0510
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0004860000335611403.
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0518 - mean_absolute_error: 0.0518 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 5.4000e-04
# Epoch 43/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - lr: 4.8600e-04
# Epoch 44/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - lr: 4.8600e-04
# Epoch 45/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0507 - mean_absolute_error: 0.0507 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - lr: 4.8600e-04
# Epoch 46/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 4.8600e-04
# Epoch 47/50
#  86/116 [=====================>........] - ETA: 0s - loss: 0.0509 - mean_absolute_error: 0.0509
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00043740003020502626.
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0511 - mean_absolute_error: 0.0511 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 4.8600e-04
# Epoch 48/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0507 - mean_absolute_error: 0.0507 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 4.3740e-04
# Epoch 49/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0498 - mean_absolute_error: 0.0498 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - lr: 4.3740e-04
# Epoch 50/50
# 116/116 [==============================] - 0s 2ms/step - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - lr: 4.3740e-04
# CPU times: user 24.1 s, sys: 10.2 s, total: 34.2 s
# Wall time: 14 s

# %%
target_nn=model.predict(features_std)
train_mae=mean_absolute_error(target,target_nn)
train_rmse=np.sqrt(mean_squared_error(target,target_nn))
train_r2=r2_score(target,target_nn)

plt.figure(figsize=(6,6))
plt.scatter(target,target_nn,c='b')
plt.plot([0.8,2],[0.8,2])
plt.xlim([0.8,2])
plt.ylim([0.8,2])
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('True',fontsize=14)
plt.ylabel('NN prediction',fontsize=14)
plt.text(1,1.9,'MAE = '+str(np.round(train_mae,3)))
plt.text(1,1.8,'R$^2$ = '+str(np.round(train_r2,3)))
plt.show()
# Out:
# 137/137 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Save NN model

# %%
# !mkdir -p NN_model
model.save('NN_model/')
# Out:
# INFO:tensorflow:Assets written to: NN_model/assets

# %%
ls NN_model
# Out:
# assets/  keras_metadata.pb  saved_model.pb  variables/

# %%
NN_model = tf.keras.models.load_model('NN_model/')

# Check its architecture
NN_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_23 (Dense)            (None, 64)                2112
#
#  dense_24 (Dense)            (None, 32)                2080
#
#  dense_25 (Dense)            (None, 16)                528
#
#  dense_26 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,737
# Trainable params: 4,737
# Non-trainable params: 0
# _________________________________________________________________
